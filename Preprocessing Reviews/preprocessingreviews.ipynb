# %%
# %pip install Wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
import re
import pandas as pd
from nltk.corpus import stopwords
from wordcloud import WordCloud, STOPWORDS
import spacy

# %%
df=pd.read_csv('D:/Semester 8/NLP/IA/sentimentanalyis_1-main/Scrapping Reviews/Scraping reviews.csv')
df.head()
# Out:
#    Unnamed: 0                                            reviews
# 0           0  \nI recently purchased a Skybag for my travels...
# 1           1  \nWorth it, right bag , right space ,right siz...
# 2           2  \nGreat quality. Good looking, and feels so co...
# 3           3  \nHolds the shape, quality is good with no tea...
# 4           4                               \nQuality is good.\n

# %%
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])

# %%
df['reviews']=df['reviews'].fillna("") #eplaced null value with a value like empty string "" or another default value

# %% [markdown]
# The first pre-processing step we’ll do is transform all reviews in reviews columns into lower case and create a new column new_reviews.

# %%
df['new_reviews'] = df['reviews'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df['new_reviews'].head()
# Out:
# 0    i recently purchased a skybag for my travels a...
# 1       worth it, right bag , right space ,right size,
# 2    great quality. good looking, and feels so comf...
# 3    holds the shape, quality is good with no tears...
# 4                                     quality is good.
# Name: new_reviews, dtype: object

# %% [markdown]
# Next, we will remove punctuation:

# %%
df['new_reviews'] = df['new_reviews'].str.replace('[^\w\s]','')
df['new_reviews'].head()
# Out:
# C:\Users\ghanc\AppData\Local\Temp\ipykernel_21848\143018513.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['new_reviews'] = df['new_reviews'].str.replace('[^\w\s]','')
# 0    i recently purchased a skybag for my travels a...
# 1           worth it right bag  right space right size
# 2    great quality good looking and feels so comfor...
# 3    holds the shape quality is good with no tears ...
# 4                                      quality is good
# Name: new_reviews, dtype: object

# %% [markdown]
# Removing emojis and pictographs(media files) in reviews

# %%
def remove_emoji(text):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags 
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)
df['new_reviews'] = df['new_reviews'].apply(lambda x: remove_emoji(x))

# %% [markdown]
# Removing Stop words like 'a' 'and 'etc

# %%
stop = stopwords.words('english')
df['new_reviews'] = df['new_reviews'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df.head(20)
# Out:
#     Unnamed: 0                                            reviews  \
# 0            0  \nI recently purchased a Skybag for my travels...
# 1            1  \nWorth it, right bag , right space ,right siz...
# 2            2  \nGreat quality. Good looking, and feels so co...
# 3            3  \nHolds the shape, quality is good with no tea...
# 4            4                               \nQuality is good.\n
# 5            5  \nI really like quality and simple look ... Tr...
# 6            6  \nUse it for 3-4 books not good for school stu...
# 7            7  \nWorth the money. Would have liked it if it w...
# 8            8                                        \nLike it\n
# 9            9                                  \nIt's nice bag\n
# 10          10  \nI recently purchased a Skybag for my travels...
# 11          11  \nWorth it, right bag , right space ,right siz...
# 12          12  \nGreat quality. Good looking, and feels so co...
# ...

# %% [markdown]
# LEmmatization (Transforming each word into its root word)

# %%
def space(comment):
    doc = nlp(comment)
    return " ".join([token.lemma_ for token in doc])
df['new_reviews']= df['new_reviews'].apply(space)
df.head(20)
# Out:
#     Unnamed: 0                                            reviews  \
# 0            0  \nI recently purchased a Skybag for my travels...
# 1            1  \nWorth it, right bag , right space ,right siz...
# 2            2  \nGreat quality. Good looking, and feels so co...
# 3            3  \nHolds the shape, quality is good with no tea...
# 4            4                               \nQuality is good.\n
# 5            5  \nI really like quality and simple look ... Tr...
# 6            6  \nUse it for 3-4 books not good for school stu...
# 7            7  \nWorth the money. Would have liked it if it w...
# 8            8                                        \nLike it\n
# 9            9                                  \nIt's nice bag\n
# 10          10  \nI recently purchased a Skybag for my travels...
# 11          11  \nWorth it, right bag , right space ,right siz...
# 12          12  \nGreat quality. Good looking, and feels so co...
# ...

# %%
df.to_csv("Pre_Processed_Reviews.csv") #saving into csv

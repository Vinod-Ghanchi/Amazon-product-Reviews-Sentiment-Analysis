# %%
# %pip install beautifulSoup
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\ghanc\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\ghanc\\AppData\\Local\\Temp\\pip-install-ugzrrew8\\beautifulsoup_22a1476818274278bd815b79137eec91\\setup.py'"'"'; __file__='"'"'C:\\Users\\ghanc\\AppData\\Local\\Temp\\pip-install-ugzrrew8\\beautifulsoup_22a1476818274278bd815b79137eec91\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\ghanc\AppData\Local\Temp\pip-pip-egg-info-0nv1ck9w'
#          cwd: C:\Users\ghanc\AppData\Local\Temp\pip-install-ugzrrew8\beautifulsoup_22a1476818274278bd815b79137eec91\
#     Complete output (6 lines):
# ...

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
search_query="school+bags"

# %%
base_url="https://www.amazon.in/s?k="

# %%
url=base_url+search_query
url
# Out:
# 'https://www.amazon.in/s?k=school+bags'

# %%
header={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36','referer':'https://www.amazon.in/s?k=school+bags&ref=nb_sb_noss'}

# %%
search_response=requests.get(url,headers=header)

# %%
search_response.status_code
# Out:
# 200

# %%
search_response.text
# Out:
# '<!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n<!-- sp:end-feature:head-start -->\n<!-- sp:feature:csm:head-open-part1 -->\n\n<script type=\'text/javascript\'>var ue_t0=ue_t0||+new Date();</script>\n<!-- sp:end-feature:csm:head-open-part1 -->\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="dns-prefetch" href="https://images-eu.ssl-images-amazon.com" crossorigin>\n<link rel="preconnect" href="https://images-eu.ssl-images-amazon.com" crossorigin>\n<link rel="dns-prefetch" href="https://m.media-amazon.com" crossorigin>\n<link rel="preconnect" href="https://m.media-amazon.com" crossorigin>\n<link rel="dns-prefetch" href="https://completion.amazon.com" crossorigin>\n<link rel="preconnect" href="https://completion.amazon.com" crossorigin>\n<!-- sp:end-feature:cs-optimization -->\n<!--
# ...

# %%
search_response.cookies
# Out:
# <RequestsCookieJar[Cookie(version=0, name='i18n-prefs', value='INR', port=None, port_specified=False, domain='.amazon.in', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=1743146480, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='session-id', value='260-8850249-1435955', port=None, port_specified=False, domain='.amazon.in', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=1743146480, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='session-id-time', value='2082787201l', port=None, port_specified=False, domain='.amazon.in', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=1743146480, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False)]>

# %% [markdown]
# function to get the content of the page of required query

# %%
cookie={} # insert request cookies within{}
def getAmazonSearch(search_query):
    url="https://www.amazon.in/s?k="+search_query
    print(url)
    page=requests.get(url,headers=header)
    if page.status_code==200:
        return page
    else:
        return "Error"

# %% [markdown]
# function to get the contents of individual product pages using 'data-asin' number (unique identification number)

# %%
def Searchasin(asin):
    url="https://www.amazon.in/dp/"+asin
    print(url)
    page=requests.get(url,cookies=cookie,headers=header)
    if page.status_code==200:
        return page
    else:
        return "Error"

# %% [markdown]
# function to pass on the link of 'see all reviews' and extract the content

# %%
def Searchreviews(review_link):
    url="https://www.amazon.in"+review_link
    print(url)
    page=requests.get(url,cookies=cookie,headers=header)
    if page.status_code==200:
        return page
    else:
        return "Error"

# %% [markdown]
# First page product reviews extraction

# %%
product_names=[]
response=getAmazonSearch('school+bags')
soup=BeautifulSoup(response.content)
for i in soup.findAll("span",{'class':'a-size-base-plus a-color-base a-text-normal'}): # the tag which is common for all the names of products
    product_names.append(i.text) #adding the product names to the list
# Out:
# https://www.amazon.in/s?k=school+bags

# %%
product_names
# Out:
# ['47 Ltrs, 46 cms School Bag Class 5-12 Large 5 partition Laptop Collage Office Travel Backpack Unisex',
#  'Raider Military Navy 30L |Stylish Trendy School College Tuition Travel Backpack with Raincover|3 Big Compartments|Padding at the Back Panel and Shoulder Straps |Made in India|1 year warranty',
#  'Casual Backpack 28L, 2 Main Compartments, Bottle Pocket, Front Pocket, Padded Shoulder Strap',
#  'BY HOTSHOT 1522|School Bag|Tuition Bag|College Backpack|ForGirls&Women|Waterproof Bag',
#  'Fizz 32L Black Backpack School bag for travel with Organizer Bottle compartment water resistant backpack',
#  'School Bag School Backpack College Backpack Travel Backpack Office Backpack Multipurpose Backpack Picnic Bag for Boys & Girls',
#  'Hitech Large Size 35 Ltrs Water Resistant Standard Backpack - Black',
#  'Aztec 37L School Bag Class 5-12 | College Bagpack for Men/College Back pack for Women | 15.6 inch Laptop Bag for Men/Backpack for Men | Spacious & Multiple Pockets (Sea Green)',
# ...

# %%
len(product_names)
# Out:
# 50

# %% [markdown]
# The method of extracting data-asin numbers are similar to that of product names. Only the tag details have to be changed in findall()

# %%
data_asin=[]
response=getAmazonSearch('school+bags')
soup=BeautifulSoup(response.content)
for i in soup.findAll("div",{'class':"sg-col-4-of-24 sg-col-4-of-12 s-result-item s-asin sg-col-4-of-16 sg-col s-widget-spacing-small sg-col-4-of-20"}):
    data_asin.append(i['data-asin'])
# Out:
# https://www.amazon.in/s?k=school+bags

# %%
data_asin
# Out:
# ['B08Z1HHHTD',
#  'B09B267161',
#  'B0C2D5B1N9',
#  'B084VQLJL8',
#  'B0C1NZLF67',
#  'B0C5X1PTYW',
#  'B07F1157TV',
#  'B0CQDB5CBZ',
#  'B0BRTFGG22',
#  'B0B21XSBWD',
#  'B079DDT65R',
#  'B07CG8BFPP',
#  'B0C23Z9W18',
#  'B0BJ5T55XY',
#  'B09HSGVMR6',
#  'B0BTHB8VYR',
#  'B0BRTCFQ5G',
#  'B0CCP8MN5W',
#  'B0BX3QFVSM',
#  'B0BNL2PBPH',
#  'B09B27B1Q6',
#  'B0B8DLBWJ2',
#  'B0C2D2XC4H',
#  'B0C2QG2K3H',
#  'B08WQ668WJ',
#  'B0B6NR8P98',
#  'B07ZJ79ZCJ',
#  'B08YZ5XY31',
#  'B08Z1Z338S',
#  'B07ZJ7VLYG',
#  'B0BG36CZD9',
#  'B0CK1FJYQ8',
#  'B0BL3SPN16',
#  'B07N8GRWTZ',
#  'B0CCL2DSC5',
#  'B07WN833M7',
#  'B097JJ2CK6',
#  'B0BKWHDS2P',
#  'B0C5LQD1WX',
#  'B08B4SJKF6',
#  'B0BZW92DSB',
#  'B07N2LC749',
#  'B08B4T53F3',
#  'B07ZJ7CJVL',
#  'B0CS6S6QZP',
#  'B07XVMR33Q',
#  'B0CSG2TY7W',
#  'B0CBRX41BP']

# %%
len(data_asin)
# Out:
# 48

# %% [markdown]
# By passing the data-asin numbers, we can extract the 'see all reviews' link for each product in the page

# %%
link=[]
for i in range(len(data_asin)):
    response=Searchasin(data_asin[i])
    soup=BeautifulSoup(response.content)
    for i in soup.findAll("a",{'data-hook':"see-all-reviews-link-foot"}):
        link.append(i['href'])
# Out:
# https://www.amazon.in/dp/B08Z1HHHTD
# https://www.amazon.in/dp/B09B267161
# https://www.amazon.in/dp/B0C2D5B1N9
# https://www.amazon.in/dp/B084VQLJL8
# https://www.amazon.in/dp/B0C1NZLF67
# https://www.amazon.in/dp/B0C5X1PTYW
# https://www.amazon.in/dp/B07F1157TV
# https://www.amazon.in/dp/B0CQDB5CBZ
# https://www.amazon.in/dp/B0BRTFGG22
# https://www.amazon.in/dp/B0B21XSBWD
# https://www.amazon.in/dp/B079DDT65R
# https://www.amazon.in/dp/B07CG8BFPP
# https://www.amazon.in/dp/B0C23Z9W18
# https://www.amazon.in/dp/B0BJ5T55XY
# https://www.amazon.in/dp/B09HSGVMR6
# https://www.amazon.in/dp/B0BTHB8VYR
# https://www.amazon.in/dp/B0BRTCFQ5G
# https://www.amazon.in/dp/B0CCP8MN5W
# https://www.amazon.in/dp/B0BX3QFVSM
# https://www.amazon.in/dp/B0BNL2PBPH
# https://www.amazon.in/dp/B09B27B1Q6
# https://www.amazon.in/dp/B0B8DLBWJ2
# https://www.amazon.in/dp/B0C2D2XC4H
# https://www.amazon.in/dp/B0C2QG2K3H
# https://www.amazon.in/dp/B08WQ668WJ
# https://www.amazon.in/dp/B0B6NR8P98
# ...

# %%
link
# Out:
# ['/Skybags-Brat-Black-Casual-Backpack/product-reviews/B08Z1HHHTD/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews',
#  '/Safari-HiTech-Water-Resistant-Backpack/product-reviews/B09B267161/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews',
#  '/Chris-Kate-School-Casual-college-Everyday-stationery-Backpack-3034/product-reviews/B0C2D5B1N9/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews',
#  '/Genie-Iridescence-Multicolor-Backpack-Resistant/product-reviews/B084VQLJL8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews',
#  '/Half-Moon-Laptop-Bag-Compartment/product-reviews/B0C1NZLF67/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews',
#  '/Skybags-Unisex-Printed-Backpack-Spiderman/product-reviews/B0C5X1PTYW/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews',
#  '/F-Gear-Raider-Marpat-Navy-Backpack/product-reviews/B07F1157TV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews',
# ...

# %%
len(link)
# Out:
# 45

# %%
reviews=[]
for j in range(len(link)):
    for k in range(100):
        response=Searchreviews(link[j]+'&pageNumber='+str(k))
        soup=BeautifulSoup(response.content)
        for i in soup.findAll("span",{'data-hook':"review-body"}):
            reviews.append(i.text)
# Out:
# https://www.amazon.in/Skybags-Brat-Black-Casual-Backpack/product-reviews/B08Z1HHHTD/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Skybags-Brat-Black-Casual-Backpack/product-reviews/B08Z1HHHTD/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Skybags-Brat-Black-Casual-Backpack/product-reviews/B08Z1HHHTD/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Skybags-Brat-Black-Casual-Backpack/product-reviews/B08Z1HHHTD/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Skybags-Brat-Black-Casual-Backpack/product-reviews/B08Z1HHHTD/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Skybags-Brat-Black-Casual-Backpack/product-reviews/B08Z1HHHTD/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# ...

# %%
len(reviews)

# %%
reviews
# Out:
# ["\nI recently purchased a Skybag for my travels and I must say, I am extremely impressed with its performance and quality.Firstly, the design of the bag is sleek and stylish. The color options available are vibrant and eye-catching, making it easy to spot my bag on the luggage carousel. The material used is durable and seems to be able to withstand rough handling during travel.One of the standout features of the Skybag is its spaciousness. The bag has ample room to fit all my essentials and more. The main compartment is roomy and can easily accommodate clothes, shoes, toiletries, and even a few extra items. Additionally, the bag has multiple pockets and compartments, allowing for easy organization of smaller items such as documents, chargers, and personal belongings.Another aspect that impressed me was the bag's comfort. The padded shoulder straps and back support make it easy to carry, even when it is fully loaded. The straps are adjustable, ensuring a comfortable fit for individua
# ...

# %%
rev={'reviews':reviews}

# %%
review_data=pd.DataFrame.from_dict(rev)
pd.set_option('max_colwidth',800)

# %%
review_data.head(5)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            reviews
# ...

# %%
review_data.shape

# %%
review_data.to_excel('Scraping reviews.xlsx') #converting the dataframe to a csv file so as to use it later for further analysis
review_data.to_csv('Scraping reviews.csv') #converting the dataframe to a csv file so as to use it later for further analysis
